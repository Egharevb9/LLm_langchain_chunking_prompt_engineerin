# %%
import ollama

# %%
response = ollama.chat(
    model="gemma3:1b",
    messages=[{"role":"users",
                "content":"How to make 6 figurs in comence?"}]
)
print(response["message"] ["content"])
# Out:
# // system.py
# import sys
#
# def main():
#     """Main function to demonstrate the system."""
#     print("Hello, world!")
#
# if __name__ == "__main__":
#     main()
# ```
#
# **Explanation:**
#
# 1.  **`import sys`:**  This line imports the `sys` module, which provides access to system-specific parameters and functions, including the command-line arguments.
#
# 2.  **`def main():`:** This defines a function named `main`.  In Python, all code execution must be within a function.
#
# 3.  **`print("Hello, world!")`:**  This is the core of the program.  It prints the string "Hello, world!" to the console.
#
# 4.  **`if __name__ == "__main__":`:** This is a standard Python idiom.  The `__name__` variable holds the name of the current script file. If the script is run directly (not imported as a module), the `__name__` variable will be set to `"__main__"`.  So, the `if` statement checks if the script is being run directly.
#
# ...
